# %% [markdown]
# importing libraries, assigning path and importing datasets

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Deepa\Documents\DataAnalytics\Data Immersion\Exercises\Achievement 4\Instacart Basket Analysis'

# %%
# import orders_products_prior to df_ords_prior

# %%
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %% [markdown]
# checking shape and data types in df_ords_prior dataset

# %%
df_ords_prior.head(15)
# Out:
#     order_id  product_id  add_to_cart_order  reordered
# 0          2       33120                  1          1
# 1          2       28985                  2          1
# 2          2        9327                  3          0
# 3          2       45918                  4          1
# 4          2       30035                  5          0
# 5          2       17794                  6          1
# 6          2       40141                  7          1
# 7          2        1819                  8          1
# 8          2       43668                  9          0
# 9          3       33754                  1          1
# 10         3       24838                  2          1
# 11         3       17704                  3          1
# 12         3       21903                  4          1
# 13         3       17668                  5          1
# 14         3       46667                  6          1

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords_prior.dtypes
# Out:
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtype: object

# %%
# import orders_checked as df_ords

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %% [markdown]
# checking shape and datatypes in df_ords dataset

# %%
df_ords.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0              0           0   2539329        1    prior             1
# 1              1           1   2398795        1    prior             2
# 2              2           2    473747        1    prior             3
# 3              3           3   2254736        1    prior             4
# 4              4           4    431534        1    prior             5
# 5              5           5   3367565        1    prior             6
# 6              6           6    550135        1    prior             7
# 7              7           7   3108588        1    prior             8
# 8              8           8   2295261        1    prior             9
# 9              9           9   2550362        1    prior            10
# 10            10          10   1187899        1    train            11
# 11            11          11   2168274        2    prior             1
# ...

# %%
df_ords.dtypes
# Out:
# Unnamed: 0.1                int64
# Unnamed: 0                  int64
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df_ords.shape
# Out:
# (3421083, 9)

# %% [markdown]
# merging df_ords and df_ords_prior on order_id

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %% [markdown]
# checking results of merge by viewing head() and value counts for _merge column

# %%
df_merged_large.head(60)
# Out:
#     Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0              0           0   2539329        1    prior             1
# 1              0           0   2539329        1    prior             1
# 2              0           0   2539329        1    prior             1
# 3              0           0   2539329        1    prior             1
# 4              0           0   2539329        1    prior             1
# 5              1           1   2398795        1    prior             2
# 6              1           1   2398795        1    prior             2
# 7              1           1   2398795        1    prior             2
# 8              1           1   2398795        1    prior             2
# 9              1           1   2398795        1    prior             2
# 10             1           1   2398795        1    prior             2
# 11             2           2    473747        1    prior             3
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# removed unnamed columns and _merge flag column from df before exporting to pkl format

# %%
df_merged_large.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1', '_merge'], inplace=True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
df_merged_large.shape
# Out:
# (32434489, 10)

# %%
count = df_merged_large.groupby('user_id').size()[1]

# %%
count
# Out:
# 59

# %%
df_merged_large.head(59)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# 5    2398795        1    prior             2                   3
# 6    2398795        1    prior             2                   3
# 7    2398795        1    prior             2                   3
# 8    2398795        1    prior             2                   3
# 9    2398795        1    prior             2                   3
# 10   2398795        1    prior             2                   3
# 11    473747        1    prior             3                   3
# 12    473747        1    prior             3                   3
# ...

# %%
df_merged_large.duplicated()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 32434484    False
# 32434485    False
# 32434486    False
# 32434487    False
# 32434488    False
# Length: 32434489, dtype: bool

# %%
print(df_merged_large.duplicated().sum())
# Out:
# 0
