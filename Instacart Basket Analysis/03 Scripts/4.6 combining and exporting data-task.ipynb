# %% [markdown]
# importing libraries, assigning path and importing data files

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Deepa\Documents\DataAnalytics\Data Immersion\Exercises\Achievement 4\Instacart Basket Analysis'

# %%
#importing combined data pickle file
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ords_prods_combined.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# 5    2398795        1    prior             2                   3
# 6    2398795        1    prior             2                   3
# 7    2398795        1    prior             2                   3
# 8    2398795        1    prior             2                   3
# 9    2398795        1    prior             2                   3
# 10   2398795        1    prior             2                   3
# 11    473747        1    prior             3                   3
# 12    473747        1    prior             3                   3
# ...

# %% [markdown]
# check shape of df_ords_prods_combined. shape is the same as the pkl file.

# %%
df_ords_prods_combined.shape
# Out:
# (32434489, 10)

# %%
#import checked products df
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods['prices'].max()
# Out:
# 99999.0

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
# dropping unnamed column from df_prods
df_prods.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# Merging the two datasets, using the product_id column as a common key. Performing an inner merge, containing only the most relevant information.
# First, we will test this merge using the pd.merge() function with these two datasets.

# %%
pd.merge(df_ords_prods_combined, df_prods, on = ['product_id'], how='inner', indicator='match')
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32404854   2977660   206209    prior            13                   1
# 32404855   2977660   206209    prior            13                   1
# 32404856   2977660   206209    prior            13                   1
# 32404857   2977660   206209    prior            13                   1
# 32404858   2977660   206209    prior            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# Performing the final merge of these two datasets

# %%
df_ords_prods_merge = df_ords_prods_combined.merge(df_prods, on='product_id', indicator='match')

# %% [markdown]
# Confirm result of merge by checking column names and value counts for the _merge column.

# %%
#confirm result of merge
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df_ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  match                   category
# dtypes: category(1), float64(2), int64(10), object(2)
# memory usage: 3.4+ GB

# %%
df_ords_prods_merge['match'].value_counts()
# Out:
# match
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# 3240859 entries contain information from both sets, which comprises the entire merged dataset.

# %% [markdown]
# Since this new dataset has a very large size, it should be exported as a .pkl file rather than .csv.

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merge.pkl'))

# %%
df_ords_prods_merge['prices'].value_counts(dropna=False)
# Out:
# prices
# 12.3    624261
# 10.3    510496
# 4.0     447272
# 6.3     438467
# 1.3     425691
#          ...
# 20.2       123
# 22.7        99
# 21.5        85
# 18.3        11
# 21.0         8
# Name: count, Length: 242, dtype: int64

# %%
df_ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %%
print((df_ords_prods_merge['prices'] == '99999.0').sum())
# Out:
# 0
